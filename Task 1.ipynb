# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


file_path = 'C:/Users/LENOVO/Downloads/API_SP.POP.TOTL_DS2_en_csv_v2_573490/API_SP.POP.TOTL_DS2_en_csv_v2_573490.csv'  # Update this with the path to your CSV file
df = pd.read_csv(file_path, skiprows=4)


df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
# Select the data for a specific year, e.g., 2020
year = '2020'
df_year = df[['Country Name', year]].dropna()

# Rename the columns for easier access
df_year.columns = ['Country', 'Population']

df_year.head
# Out:
# <bound method NDFrame.head of                          Country   Population
# 0                          Aruba     106585.0
# 1    Africa Eastern and Southern  685112979.0
# 2                    Afghanistan   38972230.0
# 3     Africa Western and Central  466189102.0
# 4                         Angola   33428486.0
# ..                           ...          ...
# 261                       Kosovo    1790133.0
# 262                  Yemen, Rep.   32284046.0
# 263                 South Africa   58801927.0
# 264                       Zambia   18927715.0
# 265                     Zimbabwe   15669666.0
#
# [265 rows x 2 columns]>

# %%
# Sort by population for better visualization
df_year = df_year.sort_values(by='Population', ascending=False)
df_year.head
# Out:
# <bound method NDFrame.head of                       Country    Population
# 259                     World  7.820206e+09
# 103          IDA & IBRD total  6.627317e+09
# 140       Low & middle income  6.549996e+09
# 156             Middle income  5.882943e+09
# 102                 IBRD only  4.867092e+09
# ..                        ...           ...
# 147  St. Martin (French part)  3.255300e+04
# 255    British Virgin Islands  3.091000e+04
# 188                     Palau  1.797200e+04
# 179                     Nauru  1.231500e+04
# 245                    Tuvalu  1.106900e+04
#
# [265 rows x 2 columns]>

# %%
# Plot a bar chart of population by country for the selected year
plt.figure(figsize=(10, 6))
sns.barplot(data=df_year.head(20), x='Population', y='Country')
plt.title(f'Top 20 Countries by Population in {year}')
plt.xlabel('Population')
plt.ylabel('Country')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Alternatively, plot a histogram of population distribution
plt.figure(figsize=(10, 6))
sns.histplot(df_year['Population'], bins=30, kde=True)
plt.title(f'Distribution of Population Sizes Across Countries in {year}')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.tight_layout()

# Show the plot
plt.show()
